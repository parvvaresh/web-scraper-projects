# %% [markdown]
# <a href="https://colab.research.google.com/github/parvvaresh/web-scraper-and-data-analyze/blob/main/data_analyze_v1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installed libraries for **Persian language** processing in Google coalb

# %%
from google.colab import output
# !pip install arabic-reshaper
# !pip install python-bidi
# !pip install hazm
output.clear()

# %% [markdown]
# Calling functions to draw **plots** and **read datasets**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from arabic_reshaper import reshape
from bidi.algorithm import get_display
from google.colab import drive
import hazm
drive.mount('/content/drive')
output.clear()

# %% [markdown]
# Reading the dataset and using important columns and see it

# %%
#read data set
data = pd.read_csv("/content/drive/MyDrive/Ai labs/web scraping/data/Data_nan.csv")

data  =  data.drop_duplicates(keep=False)

#important columns
data = data[["Title", "Abstract", "Owner", "field", "Key word", "country", "State", "City", "link of page"]]
data  =  data.drop_duplicates(keep=False)

#see it
data.head(5)
# Out:
#                                                Title  \
# 0  خشک شدن سریع، افزایش مقاومت به سایش و ماندگاری...
# 1  امکان سنجی، توسعه و بومی سازی روش های اندازه گ...
# 2  طراحی و ساخت سمپاش هایی با قدرت تشخیص علف هرز ...
# 3  کاهش میزان افت در فرایند تولید،توزیع، انبار  و...
# 4  اکسترودر دوماردونه با قابلیت تخمیر و پخت همزما...
#
#                                             Abstract  \
# 0  خشک شدن سریع رنگ بر روی کیسه و افزایش چسبندگی ...
# 1  سیلاب هر ساله خسارات زیادی به بخشهای مختلف است...
# 2  بهترین روش برای حفاظت از مزارع کشاورزی، پیشگیر...
# 3  کاهش میزان افت در فرایند تولید،توزیع، انبار  و...
# 4  در حال حاضر نمونه دستگاه اکسترودر دو ماردون جه...
#
#                               Owner  \
# 0  پژوهشگران فناوریهای پیشرفته آسیا
# 1      شرکت سهامی آب منطقه ای قزوین
# 2           پارک علم و فناوری همدان
# 3            پارک علم و فناوری فارس
# 4                               NaN
#
#                                            field  \
# 0                    علوم پایه, مهندسی محیط زیست
# 1                                            NaN
# 2                                            NaN
# 3  دامپزشکی, فنی و مهندسی, کشاورزی و منابع طبیعی
# 4             کشاورزی و منابع طبیعی, علوم بهداشت
#
#                                             Key word country   State   City  \
# 0                                                NaN   ایران  اصفهان    NaN
# 1  ['امکان سنجی-توسعه-بومی سازی-اندازه گیری-بارش ...   ایران   قزوین  قزوین
# 2              ['سمپاش هوشمند، علف هرز، گیاه زراعی']   ایران   همدان  همدان
# 3     ['کاهش افت تولید توزیع انبار  کشتارگاه سالیذ']   ایران    فارس  شیراز
# 4                                                NaN   ایران      قم    NaN
#
#                                         link of page
# 0  https://nan.ac/ViewNeed/AF159FCAAA904963F36E6C...
# 1  https://nan.ac/ViewNeed/A0B2F6EC69775DE8437499...
# 2  https://nan.ac/ViewNeed/985034DAC2683BA0C42283...
# 3  https://nan.ac/ViewNeed/997C982AF525D5F3980D47...
# 4  https://nan.ac/ViewNeed/64317CAC21FF7F75E61BDD...

# %%
data.shape
# Out:
# (4964, 9)

# %% [markdown]
# Check how many nulls each column has

# %%
null_value = dict(data.isnull().sum())
plt.figure(figsize = (10,10))
plots = sns.barplot(x = list(null_value.keys()), y = list(null_value.values()))

for bar in plots.patches:
  plots.annotate(format(bar.get_height(), '.0f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')

# %%
temp = list(data["Key word"].dropna())

key = []
for element  in temp:
  element = element[2 : -2]
  key.extend(element.split("،"))

key = ["".join(element.lstrip()) for element in key]
key = ["".join(element.rstrip()) for element in key]




counter = {}
for element in set(key):
  counter.update({element : 0})

for element in (key):
  counter[element] += 1
counter = dict(sorted(counter.items(), key = lambda item : item[1]))
labels = list(counter.keys())[-50 : -2]
value = list(counter.values())[-50 : -2]
persian_labels = [get_display(reshape(label)) for label in labels]
df = pd.DataFrame({
    "key word" : persian_labels,
    "number of repeat" : value

})


plt.figure(figsize = (50 , 10))
plots = sns.barplot(x = "key word" , y = "number of repeat", data=df)
plots.set_xticklabels(plots.get_xticklabels(),rotation = 90)

for bar in plots.patches:
  plots.annotate(format(bar.get_height(), '.0f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')
plt.savefig("/content/drive/MyDrive/Ai labs/web scraping/plot/key_word.png")

# %%
field = list(data["field"].dropna())



fields = []

for element in list(field):
  fields.extend(element.split(","))

fields = ["".join(element.lstrip()) for element in fields]
fields = ["".join(element.rstrip()) for element in fields]


counter = {}
for element in set(fields):
  counter.update({element : 0})

for element in (fields):
  counter[element] += 1

counter = dict(sorted(counter.items(), key = lambda item:item[1]))
labels = list(counter.keys())
persian_labels = [get_display(reshape(label)) for label in labels]

df = pd.DataFrame({
    "fields" : persian_labels,
    "number of repeat" : list(counter.values())

})

plt.figure(figsize = (110 , 30))
plots = sns.barplot(x = "fields" , y = "number of repeat", data=df)
plots.set_xticklabels(plots.get_xticklabels(),rotation = 90)

for bar in plots.patches:
  plots.annotate(format(bar.get_height(), '.0f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')
plt.savefig("/content/drive/MyDrive/Ai labs/web scraping/plot/fields.png")

# %%
State = dict(data["State"].value_counts())

labels = list(State.keys())
labels = [get_display(reshape(label)) for label in labels]
df = pd.DataFrame({
    "State" : labels,
    "number of repeat" : list(State.values())

})

plt.figure(figsize = (40 , 10))
plots = sns.barplot(x = "State" , y = "number of repeat", data=df)
plots.set_xticklabels(plots.get_xticklabels(),rotation = 90)

for bar in plots.patches:
  plots.annotate(format(bar.get_height(), '.0f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')
plt.savefig("/content/drive/MyDrive/Ai labs/web scraping/plot/State.png")

# %%
City = dict(data["City"].value_counts())

labels = list(State.keys())
labels = [get_display(reshape(label)) for label in labels]
df = pd.DataFrame({
    "City" : labels,
    "number of repeat" : list(State.values())

})

plt.figure(figsize = (40 , 10))
plots = sns.barplot(x = "City" , y = "number of repeat", data=df)
plots.set_xticklabels(plots.get_xticklabels(),rotation = 90)

for bar in plots.patches:
  plots.annotate(format(bar.get_height(), '.0f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')
plt.savefig("/content/drive/MyDrive/Ai labs/web scraping/plot/City.png")

# %%
# !pip install wordcloud-fa
output.clear()

# %%
from wordcloud_fa import WordCloudFa
abstract = list(data["Abstract"].dropna())
abstract = "".join(abstract)
wordcloud = WordCloudFa(persian_normalize=True, background_color='white', width=800, height=600, stopwords = hazm.stopwords_list())
wc = wordcloud.generate(abstract, )
image = wc.to_image()
image
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F80EC302970>

# %%
groups = data.groupby(['State'])

counter = {}

for State in list(data["State"].dropna().unique()):
  temp_df = groups.get_group(State)
  temp_df = temp_df.reset_index()
  field = temp_df["field"].dropna()


  fields = []

  for element in list(field):
    fields.extend(element.split(","))

  fields = ["".join(element.lstrip()) for element in fields]
  fields = ["".join(element.rstrip()) for element in fields]
  
  temp_counter = {}
  for element in set(fields):
    temp_counter.update({element : 0})

  for element in fields:
    temp_counter[element] += 1
  temp_counter = dict(sorted(temp_counter.items(), key = lambda item : item[1]))
  counter.update({State : f"{list(temp_counter.keys())[-1]} -- {list(temp_counter.values())[-1]}"})


state = dict(data["State"].value_counts())

labels = list(state.keys())

df = pd.DataFrame({
    "State" : labels,
    "number of repeat" : list(state.values())

})

df["fildes"] = ""
for key, value in counter.items():
  for index in range(0, df.shape[0]):
    if key in df.loc[index]["State"] :
      df.loc.__setitem__((index, ("fildes")), value)

def addlabels(x ,y , labels):
    for i in range(len(x)):
        plt.text(x[i], y[i], labels[i], ha = 'center', bbox = dict(facecolor = 'red', alpha =1))
x = list(df["State"])
y = list(df["number of repeat"])
label = list(df["fildes"])

x = [get_display(reshape(element)) for element in x]
label = [get_display(reshape(element)) for element in label]
plt.figure(figsize = (70, 23))
plt.bar(x, y, color = "blue") 
plt    
addlabels(x, y, label)

# %%
def extract_ai_word(df, col, key):
  ai_word = []

  df_temp = data.dropna(subset = [col])
  

  for index in range(0, df_temp.shape[0]):
    target = df_temp.iloc[index][col]
    if key in target:
      ai_word.append(df_temp.iloc[index])
  return pd.DataFrame(ai_word).reset_index()

# %%
key = "هوش مصنوعی"

extract_ai_word(data, "Key word", key).to_csv("/content/drive/MyDrive/Ai labs/web scraping/ai words/key_word_ai.csv")
extract_ai_word(data, "field", key).to_csv("/content/drive/MyDrive/Ai labs/web scraping/ai words/field_ai.csv")
extract_ai_word(data, "Abstract", key).to_csv("/content/drive/MyDrive/Ai labs/web scraping/ai words/Abstract_ai.csv")

# %%
key = "داده کاوی"

extract_ai_word(data, "Key word", key).to_csv("/content/drive/MyDrive/Ai labs/web scraping/ai words/key_word_dm.csv")
extract_ai_word(data, "field", key).to_csv("/content/drive/MyDrive/Ai labs/web scraping/ai words/field_dm.csv")
extract_ai_word(data, "Abstract", key).to_csv("/content/drive/MyDrive/Ai labs/web scraping/ai words/Abstract_dm.csv")

# %%
key = "یادگیری ماشین"

extract_ai_word(data, "Key word", key).to_csv("/content/drive/MyDrive/Ai labs/web scraping/ai words/key_word_ml.csv")
extract_ai_word(data, "field", key).to_csv("/content/drive/MyDrive/Ai labs/web scraping/ai words/field_ml.csv")
extract_ai_word(data, "Abstract", key).to_csv("/content/drive/MyDrive/Ai labs/web scraping/ai words/Abstract_ml.csv")

# %%
key =  "شبکه عصبی"

extract_ai_word(data, "Key word", key).to_csv("/content/drive/MyDrive/Ai labs/web scraping/ai words/key_word_dl.csv")
extract_ai_word(data, "field", key).to_csv("/content/drive/MyDrive/Ai labs/web scraping/ai words/field_dl.csv")
extract_ai_word(data, "Abstract", key).to_csv("/content/drive/MyDrive/Ai labs/web scraping/ai words/Abstract_dl.csv")

# %%
import os
import glob
files = os.path.join("/content/drive/MyDrive/Ai labs/web scraping/ai words", "*.csv")
files = glob.glob(files)
dfs = []
for File in files:
  dfs.append(pd.read_csv(File, error_bad_lines=False))
all_csv_file = pd.concat(dfs, ignore_index=True)


all_csv_file = all_csv_file[["Title", "Abstract", "Owner", "field", "Key word"]]

all_csv_file  = all_csv_file.drop_duplicates(keep=False)

all_csv_file.to_csv("/content/drive/MyDrive/Ai labs/web scraping/ai words/all_csv_file.csv")

# %%
ai = pd.read_csv("/content/drive/MyDrive/Ai labs/web scraping/ai words/all_csv_file.csv")

# %%
field = list(ai["field"].dropna())



fields = []

for element in list(field):
  fields.extend(element.split(","))

fields = ["".join(element.lstrip()) for element in fields]
fields = ["".join(element.rstrip()) for element in fields]


counter = {}
for element in set(fields):
  counter.update({element : 0})

for element in (fields):
  counter[element] += 1

counter = dict(sorted(counter.items(), key = lambda item:item[1]))
labels = list(counter.keys())
persian_labels = [get_display(reshape(label)) for label in labels]

df = pd.DataFrame({
    "fields" : persian_labels,
    "number of repeat" : list(counter.values())

})

plt.figure(figsize = (20 , 30))
plots = sns.barplot(x = "fields" , y = "number of repeat", data=df)
plots.set_xticklabels(plots.get_xticklabels(),rotation = 90)

for bar in plots.patches:
  plots.annotate(format(bar.get_height(), '.0f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')


plt.savefig("/content/drive/MyDrive/Ai labs/web scraping/plot/ai_files.png")

# %%
temp = list(ai["Key word"].dropna())

key = []
for element  in temp:
  element = element[2 : -2]
  key.extend(element.split("،"))

key = ["".join(element.lstrip()) for element in key]
key = ["".join(element.rstrip()) for element in key]




counter = {}
for element in set(key):
  counter.update({element : 0})

for element in (key):
  counter[element] += 1
counter = dict(sorted(counter.items(), key = lambda item : item[1]))
labels = list(counter.keys())[-50 : -2]
value = list(counter.values())[-50 : -2]
persian_labels = [get_display(reshape(label)) for label in labels]
df = pd.DataFrame({
    "key word" : persian_labels,
    "number of repeat" : value

})


plt.figure(figsize = (50 , 10))
plots = sns.barplot(x = "key word" , y = "number of repeat", data=df)
plots.set_xticklabels(plots.get_xticklabels(),rotation = 90)

for bar in plots.patches:
  plots.annotate(format(bar.get_height(), '.0f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=15, xytext=(0, 8),
                   textcoords='offset points')
  


plt.savefig("/content/drive/MyDrive/Ai labs/web scraping/plot/ai_keyword.png")
